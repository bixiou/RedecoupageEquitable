# %%
# %load_ext autoreload
# %autoreload 2

#Imports
import geopandas as gpd
import numpy as np
import pandas as pd

from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets


# Pour k-means
import districting_functions as functions

# Pour graph
import folium
import random
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
nb_circos = 335
nb_circos_metropole = 320
ratio_pop_max = 1.4

base = 'iris' # peut être 'cantons' ou 'iris'
path_iris = 'Data/iris.shp'
path_cantons = 'Data/cantons.shp'
path_nb_cantons = 'Data/nombre_cantons_par_departement_2015.csv' # list(nb_cantons[nb_cantons.departement=='55']['nb_cantons'])[0]

save_path = 'Resultats/decoupage' + str(ratio_pop_max).replace('.', '-') # _iris

# %%
data = functions.load_data(base, path_iris, merge_by_commune=True) # The second and third argument are optional

# %%
decoupage = functions.districting(data, nb_districts=nb_circos_metropole, save_path=save_path, \
                stop_criteria=ratio_pop_max, weight_step_scale=20, it_max=100000, clean=False)

# %%
# Crée la carte
# /!\ Rien ne s'affiche chez moi => passer par QGis à partir du fichier sauvegardé (decoupage.to_file(save_path))
carte = folium.Map([48.866607, 2.346882], zoom_start=13, tiles='cartodbpositron')
points = folium.features.GeoJson(data)
carte.add_children(points)
carte

# %%
iris_merged = functions.load_data(base, path_iris, merge_by_commune=True)
# Out:
# /home/adrien/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
decoupage = functions.districting(iris_merged, nb_districts=nb_circos_metropole, save_path=save_path, \
                stop_criteria=ratio_pop_max, weight_step_scale=20, it_max=10000, clean=False, path_nb_cantons=path_nb_cantons)

# %%
iris_merged[2]
# Out:
#                                                     geometry          pop  \
# lieu
# 02001      POLYGON ((715047.9999999963 6943859.500001409,...   398.709031
# 02002      POLYGON ((728078.2999999933 6953460.200001359,...   449.703947
# 02003      POLYGON ((728513.3999999921 6915217.900001569,...   755.065723
# 02004      POLYGON ((767203.1999999841 6955650.700001345,...   160.461538
# 02005      POLYGON ((772451.1999999806 6922019.900001533,...   291.475827
# 02006      POLYGON ((734681.0999999925 6981819.800001204,...   216.347656
# 02007      POLYGON ((760905.2999999842 6931148.20000148, ...    91.592920
# 02008      POLYGON ((736092.9999999905 6924182.700001517,...   217.142857
# 02009      POLYGON ((725113.4999999942 6963099.300001303,...   384.000000
# 02010      POLYGON ((731775.1999999918 6930856.600001481,...   116.971591
# 02011      POLYGON ((712900.6999999965 6918464.300001549,...   863.718810
# 02012      POLYGON ((728513.3999999921 6915217.900001569,...    56.507042
# 02013      POLYGON ((764211.7999999835 6932118.600001475,...   304.736077
# 02014      POLYGON ((721417.9999999948 6943312.800001413,...   551.319753
# 02015      POLYGON ((714886.6999999958 6903518.800001631,...    61.298701
# 02016      POLYGON ((725385.299999994 6948910.300001379, ...   145.981651
# 02017      POLYGON ((730203.699999993 6957774.400001334, ...   219.328859

# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-281-ae71e38e9758> in <module>()
#       5 # data = [None for i in range(96)]
#       6 # iris_copy['lieu'] = [str(code)[0:5] for code in iris_copy['atom']]
# ----> 7 functions.load_data.mro
#
# AttributeError: 'function' object has no attribute 'mro'

# %%
# communes = iris_copy.copy()
# communes["INSEE_COM"] = [str(code)[0:5] for code in iris_copy['CODE_IRIS']]
# communes.groupby('INSEE_COM').sum()[np.where(communes.groupby('INSEE_COM').sum().loc['01002'])]
# communes.groupby('INSEE_COM').sum().loc['01002']

# %%
# Merge by commune
# iris_copy = iris.copy()
# iris_copy["INSEE_COM"] = [str(code)[0:5] for code in iris_copy['CODE_IRIS']]
# iris_copy = iris_copy.dissolve("NOM_COM", aggfunc="sum")
# iris_copy.crs = iris.crs
# iris_copy["INSEE_COM"] = iris_copy.index

# %%
# iris_merged = iris_merged.dissolve("NOM_COM", aggfunc="sum")
# iris_merged_copy2 = iris_filtered.dissolve("INSEE_COM", aggfunc="sum")

# iris = gpd.read_file(path_iris)
# iris_copy = iris.copy()
# iris_copy["INSEE_COM"] = [str(code)[0:5] for code in iris_copy['CODE_IRIS']]

# iris_merged = [None for i in range(96)]
# for i in range(1, 96):
#     if i < 10:        departement = "0"+str(i)
#     else:        departement = str(i)
#     if i!=20:
#         try: 
#             iris_filtered = iris_copy[iris_copy["CODE_IRIS"].str.startswith(departement)].copy()
#             iris_filtered = iris_filtered.dissolve("INSEE_COM", aggfunc="sum")
#             iris_filtered.crs = iris.crs
#             iris_merged[i] = iris_filtered
#         except: print('Departement', i, 'has a problem') # 1, 30, 37, 69, 79
# Out:
# [autoreload of districting_functions failed: Traceback (most recent call last):
#   File "/home/adrien/anaconda3/lib/python3.5/site-packages/IPython/extensions/autoreload.py", line 246, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/adrien/anaconda3/lib/python3.5/site-packages/IPython/extensions/autoreload.py", line 369, in superreload
#     module = reload(module)
#   File "/home/adrien/anaconda3/lib/python3.5/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/adrien/anaconda3/lib/python3.5/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 693, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 799, in get_code
#   File "<frozen importlib._bootstrap_external>", line 759, in source_to_code
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "/var/www/RedecoupageEquitable/districting_functions.py", line 45
#     def districting(data, nb_districts, save_path, stop_criteria=1.5, weight_step_scale=20, it_max=100000, clean=False, path_nb_cantons):
#                    ^
# SyntaxError: non-default argument follows default argument
# ]
